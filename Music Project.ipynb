# %%
import pandas as pd
song = pd.read_csv("SongList.csv")
song
# Out:
#         Year    Actor                  Movie                     Songs  \
# 0     1977.0   Rajini              Kavikuyil  Chinna Kannan Azhaikiran
# 1     1977.0   Rajini  Bhuvana Oru Kelvikuri     Vizhiyile Malarndhadu
# 2     1977.0   Rajini  Bhuvana Oru Kelvikuri                Raja Enbar
# 3     1978.0   Rajini         Mullum Malarum          Senthalam Poovil
# 4     1978.0   Rajini         Mullum Malarum            Raman Aandalum
# ...      ...      ...                    ...                       ...
# 1240  2018.0  Dhanush           Vada Chennai     Kaarkuzhal Kadavaaiye
# 1241  2018.0  Dhanush           Vada Chennai         Ennadi Mayavi Nee
# 1242  2020.0    Jeeva                  Gypsy   Manamengum Maaya Oonjal
# 1243  2021.0      NaN                Karnann       Kanda Vara Sollunga
# 1244  2021.0      NaN                Karnann        Manjanathi Puranam
#
#                                    Singer Music Director       Director
# ...

# %%
import plotly.graph_objs as go
import pandas as pd

# Count movies per actor
movies_per_actor = song.groupby('Actor')['Movie'].nunique().sort_values(ascending=False)

# Select top 15 actors by number of movies
top_actors = movies_per_actor.head(15)

# Create a Plotly bar chart with annotations
data_movies_per_actor = go.Bar(
    x=top_actors.index,
    y=top_actors.values,
    marker=dict(color='skyblue'),
    text=top_actors.values,
    textposition='auto',
)

layout_movies_per_actor = go.Layout(
    title='Top 15 Actors by Number of Movies',
    xaxis=dict(title='Actor'),
    yaxis=dict(title='Number of Movies'),
    height=800,
)

fig_movies_per_actor = go.Figure(data=[data_movies_per_actor], layout=layout_movies_per_actor)

# Update layout for aesthetic improvements
fig_movies_per_actor.update_traces(textfont_size=12, textfont_color='black')  # Text font size and color
fig_movies_per_actor.update_layout(plot_bgcolor='rgba(0,0,0,0)',  # Transparent plot background
                                   paper_bgcolor='rgba(0,0,0,0)',  # Transparent paper background
                                   font=dict(family="Arial, sans-serif", size=14, color='darkslategray'),  # Font settings
                                   title=dict(x=0.5, y=0.95, font=dict(size=24)),  # Title position and style
                                   xaxis=dict(tickfont=dict(size=12)),  # X-axis tick font size
                                   yaxis=dict(tickfont=dict(size=12)),  # Y-axis tick font size
                                   )

# Display plot
fig_movies_per_actor.show()

# %%
# Count songs per actor
songs_per_actor = song.groupby('Actor')['Songs'].count().sort_values(ascending=False)

# Select top 15 actors by number of songs
top_actors_songs = songs_per_actor.head(15)

# Create a Plotly bar chart with annotations
data_songs_per_actor = go.Bar(
    x=top_actors_songs.index,
    y=top_actors_songs.values,
    marker=dict(color='lightgreen'),
    text=top_actors_songs.values,
    textposition='auto',
)

layout_songs_per_actor = go.Layout(
    title='Top 15 Actors by Number of Songs',
    xaxis=dict(title='Actor'),
    yaxis=dict(title='Number of Songs'),
    height=800,
)

fig_songs_per_actor = go.Figure(data=[data_songs_per_actor], layout=layout_songs_per_actor)

# Update layout for aesthetic improvements
fig_songs_per_actor.update_traces(textfont_size=12, textfont_color='black')  # Text font size and color
fig_songs_per_actor.update_layout(plot_bgcolor='rgba(0,0,0,0)',  # Transparent plot background
                                  paper_bgcolor='rgba(0,0,0,0)',  # Transparent paper background
                                  font=dict(family="Arial, sans-serif", size=14, color='darkslategray'),  # Font settings
                                  title=dict(x=0.5, y=0.95, font=dict(size=24)),  # Title position and style
                                  xaxis=dict(tickfont=dict(size=12)),  # X-axis tick font size
                                  yaxis=dict(tickfont=dict(size=12)),  # Y-axis tick font size
                                  )

# Display plot
fig_songs_per_actor.show()

# %%
# Count movies per music director
movies_per_music_director = song.groupby('Music Director')['Movie'].nunique().sort_values(ascending=False)

# Select top 15 music directors by number of movies
top_music_directors = movies_per_music_director.head(15)

# Create a Plotly bar chart with annotations
data_movies_per_director = go.Bar(
    x=top_music_directors.index,
    y=top_music_directors.values,
    marker=dict(color='orange'),
    text=top_music_directors.values,
    textposition='auto',
)

layout_movies_per_director = go.Layout(
    title='Top 15 Music Directors by Number of Movies',
    xaxis=dict(title='Music Director'),
    yaxis=dict(title='Number of Movies'),
    height=800,
)

fig_movies_per_director = go.Figure(data=[data_movies_per_director], layout=layout_movies_per_director)

# Update layout for aesthetic improvements
fig_movies_per_director.update_traces(textfont_size=12, textfont_color='black')  # Text font size and color
fig_movies_per_director.update_layout(plot_bgcolor='rgba(0,0,0,0)',  # Transparent plot background
                                      paper_bgcolor='rgba(0,0,0,0)',  # Transparent paper background
                                      font=dict(family="Arial, sans-serif", size=14, color='darkslategray'),  # Font settings
                                      title=dict(x=0.5, y=0.95, font=dict(size=24)),  # Title position and style
                                      xaxis=dict(tickfont=dict(size=12)),  # X-axis tick font size
                                      yaxis=dict(tickfont=dict(size=12)),  # Y-axis tick font size
                                      )

# Display plot
fig_movies_per_director.show()

# %%
# Count songs per year
songs_per_year = song.groupby('Year')['Songs'].count()

# Create a Plotly line chart with annotations
data_songs_per_year = go.Scatter(
    x=songs_per_year.index,
    y=songs_per_year.values,
    mode='lines+markers',
    marker=dict(color='purple', size=10),
    text=[f'Year: {year}<br>Songs: {songs}' for year, songs in zip(songs_per_year.index, songs_per_year.values)],
    hoverinfo='text',
)

layout_songs_per_year = go.Layout(
    title='Number of Songs Released Each Year',
    xaxis=dict(title='Year'),
    yaxis=dict(title='Number of Songs'),
    height=800,
)

fig_songs_per_year = go.Figure(data=[data_songs_per_year], layout=layout_songs_per_year)

# Update layout for aesthetic improvements
fig_songs_per_year.update_traces(textfont_size=12, textfont_color='black')  # Text font size and color
fig_songs_per_year.update_layout(plot_bgcolor='rgba(0,0,0,0)',  # Transparent plot background
                                 paper_bgcolor='rgba(0,0,0,0)',  # Transparent paper background
                                 font=dict(family="Arial, sans-serif", size=14, color='darkslategray'),  # Font settings
                                 title=dict(x=0.5, y=0.95, font=dict(size=24)),  # Title position and style
                                 xaxis=dict(tickfont=dict(size=12)),  # X-axis tick font size
                                 yaxis=dict(tickfont=dict(size=12)),  # Y-axis tick font size
                                 )

# Display plot
fig_songs_per_year.show()

# %%
import pandas as pd

# Assuming 'Year' column is in integer format
song['Decade'] = song['Year'] // 10 * 10  # Create a new column for decade

# Aggregate number of songs per decade
songs_per_decade = song.groupby('Decade')['Songs'].count()

# Aggregate number of unique music directors per decade
unique_music_directors_per_decade = song.groupby('Decade')['Music Director'].nunique()

# Aggregate number of unique directors per decade
unique_directors_per_decade = song.groupby('Decade')['Director'].nunique()

# Aggregate number of unique actors per decade
unique_actors_per_decade = song.groupby('Decade')['Actor'].nunique()

# Combine all aggregated data into a DataFrame
decade_stats = pd.DataFrame({
    'Songs': songs_per_decade,
    'Unique Music Directors': unique_music_directors_per_decade,
    'Unique Directors': unique_directors_per_decade,
    'Unique Actors': unique_actors_per_decade
})

# Print aggregated statistics
print("Decade-wise Statistics:")
print(decade_stats)
# Out:
# Decade-wise Statistics:
#         Songs  Unique Music Directors  Unique Directors  Unique Actors
# Decade
# 1950.0     50                      14                10              3
# 1960.0    162                      11                16              3
# 1970.0    119                       7                19              8
# 1980.0    226                       7                20             11
# 1990.0    226                      11                20             16
# 2000.0    205                      16                19             15
# 2010.0    196                      11                14             12
# 2020.0     59                       4                 8             11

# %%
import plotly.graph_objs as go

# Create a Plotly bar chart for songs per decade
data_songs_per_decade = go.Bar(
    x=decade_stats.index,
    y=decade_stats['Songs'],
    marker=dict(color='purple'),
    text=decade_stats['Songs'],
    textposition='outside',  # Place text outside the bars for better visibility
)

layout_songs_per_decade = go.Layout(
    title='Number of Songs Released Each Decade',
    xaxis=dict(title='Decade'),
    yaxis=dict(title='Number of Songs'),
    height=800,
)

fig_songs_per_decade = go.Figure(data=[data_songs_per_decade], layout=layout_songs_per_decade)

# Update layout for aesthetic improvements
fig_songs_per_decade.update_traces(textfont_size=16, textfont_color='black', insidetextanchor='start')  # Increase text font size and set color
fig_songs_per_decade.update_layout(plot_bgcolor='rgba(255, 255, 255, 0.9)',  # Lighter transparent plot background
                                   paper_bgcolor='rgba(255, 255, 255, 0.9)',  # Lighter transparent paper background
                                   font=dict(family="Arial, sans-serif", size=18, color='darkslategray'),  # Font settings
                                   title=dict(x=0.5, y=0.95, font=dict(size=28)),  # Title position and style
                                   xaxis=dict(tickfont=dict(size=14)),  # X-axis tick font size
                                   yaxis=dict(tickfont=dict(size=14)),  # Y-axis tick font size
                                   )

# Display plot
fig_songs_per_decade.show()

# %%
# Create a Plotly bar chart for unique music directors per decade
data_music_directors_per_decade = go.Bar(
    x=decade_stats.index,
    y=decade_stats['Unique Music Directors'],
    marker=dict(color='blue'),
    text=decade_stats['Unique Music Directors'],
    textposition='outside',  # Place text outside the bars for better visibility
)

layout_music_directors_per_decade = go.Layout(
    title='Number of Unique Music Directors Each Decade',
    xaxis=dict(title='Decade'),
    yaxis=dict(title='Number of Unique Music Directors'),
    height=800,
)

fig_music_directors_per_decade = go.Figure(data=[data_music_directors_per_decade], layout=layout_music_directors_per_decade)

# Update layout for aesthetic improvements
fig_music_directors_per_decade.update_traces(textfont_size=16, textfont_color='black', insidetextanchor='start')  # Increase text font size and set color
fig_music_directors_per_decade.update_layout(plot_bgcolor='rgba(255, 255, 255, 0.9)',  # Lighter transparent plot background
                                             paper_bgcolor='rgba(255, 255, 255, 0.9)',  # Lighter transparent paper background
                                             font=dict(family="Arial, sans-serif", size=18, color='darkslategray'),  # Font settings
                                             title=dict(x=0.5, y=0.95, font=dict(size=28)),  # Title position and style
                                             xaxis=dict(tickfont=dict(size=14)),  # X-axis tick font size
                                             yaxis=dict(tickfont=dict(size=14)),  # Y-axis tick font size
                                             )

# Display plot
fig_music_directors_per_decade.show()

# %%
# Create a Plotly bar chart for unique directors per decade
data_directors_per_decade = go.Bar(
    x=decade_stats.index,
    y=decade_stats['Unique Directors'],
    marker=dict(color='green'),
    text=decade_stats['Unique Directors'],
    textposition='outside',  # Place text outside the bars for better visibility
)

layout_directors_per_decade = go.Layout(
    title='Number of Unique Directors Each Decade',
    xaxis=dict(title='Decade'),
    yaxis=dict(title='Number of Unique Directors'),
    height=800,
)

fig_directors_per_decade = go.Figure(data=[data_directors_per_decade], layout=layout_directors_per_decade)

# Update layout for aesthetic improvements
fig_directors_per_decade.update_traces(textfont_size=16, textfont_color='black', insidetextanchor='start')  # Increase text font size and set color
fig_directors_per_decade.update_layout(plot_bgcolor='rgba(255, 255, 255, 0.9)',  # Lighter transparent plot background
                                       paper_bgcolor='rgba(255, 255, 255, 0.9)',  # Lighter transparent paper background
                                       font=dict(family="Arial, sans-serif", size=18, color='darkslategray'),  # Font settings
                                       title=dict(x=0.5, y=0.95, font=dict(size=28)),  # Title position and style
                                       xaxis=dict(tickfont=dict(size=14)),  # X-axis tick font size
                                       yaxis=dict(tickfont=dict(size=14)),  # Y-axis tick font size
                                       )

# Display plot
fig_directors_per_decade.show()

# %%
# Create a Plotly bar chart for unique actors per decade
data_actors_per_decade = go.Bar(
    x=decade_stats.index,
    y=decade_stats['Unique Actors'],
    marker=dict(color='orange'),
    text=decade_stats['Unique Actors'],
    textposition='outside',  # Place text outside the bars for better visibility
)

layout_actors_per_decade = go.Layout(
    title='Number of Unique Actors Each Decade',
    xaxis=dict(title='Decade'),
    yaxis=dict(title='Number of Unique Actors'),
    height=800,
)

fig_actors_per_decade = go.Figure(data=[data_actors_per_decade], layout=layout_actors_per_decade)

# Update layout for aesthetic improvements
fig_actors_per_decade.update_traces(textfont_size=16, textfont_color='black', insidetextanchor='start')  # Increase text font size and set color
fig_actors_per_decade.update_layout(plot_bgcolor='rgba(255, 255, 255, 0.9)',  # Lighter transparent plot background
                                    paper_bgcolor='rgba(255, 255, 255, 0.9)',  # Lighter transparent paper background
                                    font=dict(family="Arial, sans-serif", size=18, color='darkslategray'),  # Font settings
                                    title=dict(x=0.5, y=0.95, font=dict(size=28)),  # Title position and style
                                    xaxis=dict(tickfont=dict(size=14)),  # X-axis tick font size
                                    yaxis=dict(tickfont=dict(size=14)),  # Y-axis tick font size
                                    )

# Display plot
fig_actors_per_decade.show()

# %%
import plotly.graph_objs as go

# Assuming 'song' DataFrame and necessary imports are already defined

# Count movies and songs per director
director_stats = song.groupby('Director').agg({'Movie': 'nunique', 'Songs': 'count'}).reset_index()

# Sort by number of songs in descending order
director_stats = director_stats.sort_values(by='Songs', ascending=False)

# Select top 15 directors by number of songs
top_directors = director_stats.head(15)

# Create a Plotly horizontal bar chart
data_director_stats = [
    go.Bar(
        y=top_directors['Director'],
        x=top_directors['Movie'],
        orientation='h',
        name='Movies',
        marker=dict(color='lightblue'),
        text=top_directors['Movie'],
        textposition='outside',  # Display text outside the bars
    ),
    go.Bar(
        y=top_directors['Director'],
        x=top_directors['Songs'],
        orientation='h',
        name='Songs',
        marker=dict(color='lightgreen'),
        text=top_directors['Songs'],
        textposition='outside',  # Display text outside the bars
    )
]

layout_director_stats = go.Layout(
    title='Top 15 Directors by Number of Movies and Songs',
    barmode='stack',
    xaxis=dict(title='Count'),
    yaxis=dict(title='Director'),
    height=800,
)

fig_director_stats = go.Figure(data=data_director_stats, layout=layout_director_stats)

# Update layout for aesthetic improvements
fig_director_stats.update_traces(textfont_size=14, textfont_color='black')  # Increase text font size and set color
fig_director_stats.update_layout(plot_bgcolor='rgba(255, 255, 255, 0.9)',  # Lighter transparent plot background
                                 paper_bgcolor='rgba(255, 255, 255, 0.9)',  # Lighter transparent paper background
                                 font=dict(family="Arial, sans-serif", size=18, color='darkslategray'),  # Font settings
                                 title=dict(x=0.5, y=0.95, font=dict(size=28)),  # Title position and style
                                 xaxis=dict(tickfont=dict(size=14)),  # X-axis tick font size
                                 yaxis=dict(tickfont=dict(size=14)),  # Y-axis tick font size
                                 )

# Display plot
fig_director_stats.show()

# %%
import plotly.graph_objs as go

# Count songs per singer
songs_per_singer = song.groupby('Singer')['Songs'].count().reset_index().sort_values(by='Songs', ascending=False)

# Select top 10 singers by number of songs
top_singers = songs_per_singer.head(10)

# Create a Plotly pie chart
fig_songs_distribution = go.Figure(
    go.Pie(
        labels=top_singers['Singer'],
        values=top_singers['Songs'],
        hole=0.3,
    )
)

fig_songs_distribution.update_layout(
    title='Distribution of Songs Across Top 10 Singers',
    font=dict(family="Arial, sans-serif", size=14, color='darkslategray'),  # Font settings
    title_font_size=24,
    plot_bgcolor='rgba(255, 255, 255, 0.9)',  # Lighter transparent plot background
    paper_bgcolor='rgba(255, 255, 255, 0.9)',  # Lighter transparent paper background
)

fig_songs_distribution.show()

# %%
# Count songs per singer
songs_per_singer = song.groupby('Singer')['Songs'].count().reset_index().sort_values(by='Songs', ascending=False)

# Select top 15 singers by number of songs
top_singers = songs_per_singer.head(15)

# Create a Plotly horizontal bar chart
fig_top_singers = go.Figure(
    go.Bar(
        y=top_singers['Singer'],
        x=top_singers['Songs'],
        orientation='h',
        marker_color='lightgreen',
        text=top_singers['Songs'],
        textposition='outside',  # Display text outside the bars
    )
)

fig_top_singers.update_layout(
    title='Top 15 Singers by Number of Songs',
    xaxis=dict(title='Number of Songs'),
    yaxis=dict(title='Singer'),
    height=800,
    plot_bgcolor='rgba(255, 255, 255, 0.9)',  # Lighter transparent plot background
    paper_bgcolor='rgba(255, 255, 255, 0.9)',  # Lighter transparent paper background
    font=dict(family="Arial, sans-serif", size=14, color='darkslategray'),  # Font settings
    title_font_size=24,
    xaxis_tickfont_size=12,
    yaxis_tickfont_size=12,
)

fig_top_singers.show()

# %%
import plotly.graph_objs as go

# Aggregate data by year
movies_songs_year = song.groupby('Year').agg({'Movie': 'nunique', 'Songs': 'count'}).reset_index()

# Create a scatter plot
fig_movies_songs_year = go.Figure(
    go.Scatter(
        x=movies_songs_year['Year'],
        y=movies_songs_year['Songs'],
        mode='lines+markers',
        marker=dict(color='purple', size=10),
        name='Songs',
        text=[f'Year: {year}<br>Songs: {songs}<br>Movies: {movies}' 
              for year, songs, movies in zip(movies_songs_year['Year'], 
                                             movies_songs_year['Songs'], 
                                             movies_songs_year['Movie'])],
        hoverinfo='text'
    )
)

fig_movies_songs_year.add_trace(
    go.Scatter(
        x=movies_songs_year['Year'],
        y=movies_songs_year['Movie'],
        mode='lines+markers',
        marker=dict(color='blue', size=10),
        name='Movies',
        text=[f'Year: {year}<br>Songs: {songs}<br>Movies: {movies}' 
              for year, songs, movies in zip(movies_songs_year['Year'], 
                                             movies_songs_year['Songs'], 
                                             movies_songs_year['Movie'])],
        hoverinfo='text'
    )
)

fig_movies_songs_year.update_layout(
    title='Number of Movies and Songs per Year',
    xaxis=dict(title='Year'),
    yaxis=dict(title='Count'),
    height=600,
    plot_bgcolor='rgba(255, 255, 255, 0.9)',  # Lighter transparent plot background
    paper_bgcolor='rgba(255, 255, 255, 0.9)',  # Lighter transparent paper background
    font=dict(family="Arial, sans-serif", size=14, color='darkslategray'),  # Font settings
)

fig_movies_songs_year.show()

# %%
# Count number of movies per director and actor combination
movies_by_director_actor = song.groupby(['Director', 'Actor'])['Movie'].nunique().reset_index()

# Select top 10 combinations by number of movies
top_combinations = movies_by_director_actor.sort_values(by='Movie', ascending=False).head(10)

# Create a Plotly grouped bar chart
fig_movies_director_actor = go.Figure()

for actor, group in top_combinations.groupby('Actor'):
    fig_movies_director_actor.add_trace(
        go.Bar(
            x=group['Director'],
            y=group['Movie'],
            name=actor,
            text=group['Movie'],
            textposition='auto',
        )
    )

fig_movies_director_actor.update_layout(
    barmode='group',
    title='Number of Movies by Director and Actor (Top 10 Combinations)',
    xaxis=dict(title='Director'),
    yaxis=dict(title='Number of Movies'),
    height=800,
    plot_bgcolor='rgba(255, 255, 255, 0.9)',  # Lighter transparent plot background
    paper_bgcolor='rgba(255, 255, 255, 0.9)',  # Lighter transparent paper background
    font=dict(family="Arial, sans-serif", size=14, color='darkslategray'),  # Font settings
)

fig_movies_director_actor.show()

# %%
# Count songs per year and actor
songs_per_year_actor = song.groupby(['Year', 'Actor'])['Songs'].count().reset_index()

# Select top 5 actors by total number of songs
top_actors = songs_per_year_actor.groupby('Actor')['Songs'].sum().nlargest(5).index

# Filter data for top actors
songs_per_year_actor_top = songs_per_year_actor[songs_per_year_actor['Actor'].isin(top_actors)]

# Create a Plotly line plot
fig_songs_over_time_actor = go.Figure()

for actor, data in songs_per_year_actor_top.groupby('Actor'):
    fig_songs_over_time_actor.add_trace(
        go.Scatter(
            x=data['Year'],
            y=data['Songs'],
            mode='lines+markers',
            name=actor,
            marker=dict(size=10),
            text=data['Songs'],
            hoverinfo='text',
        )
    )

fig_songs_over_time_actor.update_layout(
    title='Number of Songs Over Time by Actor (Top 5)',
    xaxis=dict(title='Year'),
    yaxis=dict(title='Number of Songs'),
    height=600,
    plot_bgcolor='rgba(255, 255, 255, 0.9)',  # Lighter transparent plot background
    paper_bgcolor='rgba(255, 255, 255, 0.9)',  # Lighter transparent paper background
    font=dict(family="Arial, sans-serif", size=14, color='darkslategray'),  # Font settings
)

fig_songs_over_time_actor.show()

# %%
# Count songs per actor and director combination
songs_per_actor_director = song.groupby(['Actor', 'Director'])['Songs'].count().reset_index()

# Select top 10 combinations by number of songs
top_combinations = songs_per_actor_director.sort_values(by='Songs', ascending=False).head(10)

# Create a Plotly scatter plot
fig_songs_actor_director = go.Figure(
    go.Scatter(
        x=top_combinations['Director'],
        y=top_combinations['Actor'],
        mode='markers',
        marker=dict(size=top_combinations['Songs']*2, color=top_combinations['Songs'], colorscale='Viridis', showscale=True),
        text=top_combinations['Songs'],
        hoverinfo='text',
    )
)

fig_songs_actor_director.update_layout(
    title='Number of Songs by Actor and Director (Top 10 Combinations)',
    xaxis=dict(title='Director'),
    yaxis=dict(title='Actor'),
    height=800,
    plot_bgcolor='rgba(255, 255, 255, 0.9)',  # Lighter transparent plot background
    paper_bgcolor='rgba(255, 255, 255, 0.9)',  # Lighter transparent paper background
    font=dict(family="Arial, sans-serif", size=14, color='darkslategray'),  # Font settings
)

fig_songs_actor_director.show()
